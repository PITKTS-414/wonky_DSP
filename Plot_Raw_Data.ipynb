# %%
# This Notebook is to look at the raw data from the sensors in both the time domain and frequency domain

# %%
# The autoreload extension will auto-refresh the changes made in filtering.py without needing to restart the kernel.
# Just remember to save your changes (cmd + s) in your .py file!
# %load_ext autoreload
# %autoreload 2
# Import a couple of classes.
from filtering import ObtainData
from filtering import BasicPlottingFiltering
from leak_detection import LeakDetection
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Time to plot!

# Test 1, no leak & passive
plot_test_number_1 = BasicPlottingFiltering(1)
plot_test_number_1.plot_raw_data_in_time()
plot_test_number_1.plot_raw_data_in_frequency()
plot_test_number_1.bandpass_FIR_filter(30,50)

# Test 40, leak & passive
plot_test_number_40 = BasicPlottingFiltering(40)
plot_test_number_40.plot_raw_data_in_time()
plot_test_number_40.plot_raw_data_in_frequency()

# Test 71, leak & passive
plot_test_number_71 = BasicPlottingFiltering(71)
plot_test_number_71.plot_raw_data_in_time()
plot_test_number_71.plot_raw_data_in_frequency()

# %%
# This line will convert this notebook into a .py file.
# ! to indicate that it is a shell command, not Python!
# Just make sure to save before you run everything!
# !jupyter nbconvert --to script /home/jovyan/SRI_Lab/Code/Plot_Raw_Data.ipynb --output-dir=/home/jovyan/SRI_Lab/Code/Notebooks_Transformed_To_Pys
# Out:
# [NbConvertApp] Converting notebook /home/jovyan/SRI_Lab/Code/Plot_Raw_Data.ipynb to script
# [NbConvertApp] Writing 1211 bytes to /home/jovyan/SRI_Lab/Code/Notebooks_Transformed_To_Pys/Plot_Raw_Data.py
